# %%
import pandas as pd

# %%
pd.read_csv("E:/PYTHAN/iNeuron/DataSet_Pandas/AgentLogingReport.csv")
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1 = pd.read_csv("E:/PYTHAN/iNeuron/DataSet_Pandas/AgentLogingReport.csv")

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
pd.read_csv("E:/PYTHAN/iNeuron/DataSet_Pandas/AgentPerformance (2).csv")
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2 = pd.read_csv("E:/PYTHAN/iNeuron/DataSet_Pandas/AgentPerformance (2).csv")

# %%
df2
# Out:
#       SL No       Date          Agent Name  Total Chats Average Response Time  \
# 0         1  7/30/2022        Prerna Singh           11               0:00:38
# 1         2  7/30/2022       Nandani Gupta           11               0:01:15
# 2         3  7/30/2022          Ameya Jain           14               0:00:30
# 3         4  7/30/2022       Mahesh Sarade           14               0:01:04
# 4         5  7/30/2022              Swati            14               0:01:11
# ...     ...        ...                 ...          ...                   ...
# 2155   2156   7/1/2022   Sowmiya Sivakumar            0               0:00:00
# 2156   2157   7/1/2022             Nitin M            0               0:00:00
# 2157   2158   7/1/2022              Vivek             0               0:00:00
# 2158   2159   7/1/2022       Ayushi Mishra            0               0:00:00
# 2159   2160   7/1/2022  Chaitra K Hiremath            0               0:00:00
#
# ...

# %%
df2.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %%
df2['Date']
# Out:
# 0       7/30/2022
# 1       7/30/2022
# 2       7/30/2022
# 3       7/30/2022
# 4       7/30/2022
#           ...
# 2155     7/1/2022
# 2156     7/1/2022
# 2157     7/1/2022
# 2158     7/1/2022
# 2159     7/1/2022
# Name: Date, Length: 2160, dtype: object

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
df2.head()
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
# 2      3 2022-07-30     Ameya Jain           14               0:00:30
# 3      4 2022-07-30  Mahesh Sarade           14               0:01:04
# 4      5 2022-07-30         Swati            14               0:01:11
#
#   Average Resolution Time  Average Rating  Total Feedback
# 0                 0:04:20            4.11               9
# 1                 0:28:25            3.14               7
# 2                 0:11:36            4.55              11
# 3                 0:15:46            4.71               7
# 4                 0:16:33            3.67               6

# %%
df2.dtypes
# Out:
# SL No                               int64
# Date                       datetime64[ns]
# Agent Name                         object
# Total Chats                         int64
# Average Response Time              object
# Average Resolution Time            object
# Average Rating                    float64
# Total Feedback                      int64
# dtype: object

# %%
df1['Date'] = pd.to_datetime(df1['Date'])

# %%
df1.dtypes
# Out:
# SL No                   int64
# Agent                  object
# Date           datetime64[ns]
# Login Time             object
# Logout Time            object
# Duration               object
# dtype: object

# %%
# 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

df2['Average Rating']
# Out:
# 0       4.11
# 1       3.14
# 2       4.55
# 3       4.71
# 4       3.67
#         ...
# 2155    0.00
# 2156    0.00
# 2157    0.00
# 2158    0.00
# 2159    0.00
# Name: Average Rating, Length: 2160, dtype: float64

# %%
df2['conv_week'] = df2['Date'].dt.week
# Out:
# <ipython-input-21-2cc60ecf58c8>:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['conv_week'] = df2['Date'].dt.week

# %%
df2['conv_date'] = df2['Date'].dt.day

# %%
df2.head(3)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
# 2      3 2022-07-30     Ameya Jain           14               0:00:30
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
# 2                 0:11:36            4.55              11         30
#
#    conv_date
# 0         30
# 1         30
# 2         30

# %%
avg_rating = df2.groupby(['Agent Name', 'conv_week'])['Average Rating'].mean().to_frame()

# %%
avg_rating
# Out:
#                       Average Rating
# Agent Name conv_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %%
# 2 .Total working days for each agents 

df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration
# 0        1  Shivananda Sonwane 2022-07-30   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya 2022-07-30   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta 2022-07-30   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi 2022-07-30   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh 2022-07-30   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A 2022-07-20   09:03:51    15:02:28   05:58:37
# 996    997             Bharath 2022-07-20   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya 2022-07-20   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain 2022-07-20   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun 2022-07-01   01:52:47    12:01:07  514:08:20
#
# [1000 rows x 6 columns]

# %%
df1.groupby(['Agent']).count()
# Out:
#                         SL No  Date  Login Time  Logout Time  Duration
# Agent
# Aditya Shinde               1     1           1            1         1
# Aditya_iot                  9     9           9            9         9
# Amersh                      4     4           4            4         4
# Ameya Jain                 10    10          10           10        10
# Ankitjha                    4     4           4            4         4
# Anurag Tiwari              37    37          37           37        37
# Aravind                    10    10          10           10        10
# Ayushi Mishra              18    18          18           18        18
# Bharath                     9     9           9            9         9
# Boktiar Ahmed Bappy        17    17          17           17        17
# Chaitra K Hiremath         13    13          13           13        13
# Deepranjan Gupta           58    58          58           58        58
# ...

# %%
working_days = df1.groupby(['Agent'])['Date'].count().to_frame()

# %%
working_days
# Out:
#                         Date
# Agent
# Aditya Shinde              1
# Aditya_iot                 9
# Amersh                     4
# Ameya Jain                10
# Ankitjha                   4
# Anurag Tiwari             37
# Aravind                   10
# Ayushi Mishra             18
# Bharath                    9
# Boktiar Ahmed Bappy       17
# Chaitra K Hiremath        13
# Deepranjan Gupta          58
# Dibyanshu                208
# Harikrishnan Shaji        23
# Hrisikesh Neogi           37
# Hyder Abbas                2
# Ineuron Intelligence       1
# Ishawant Kumar            49
# Jawala Prakash            16
# Jaydeep Dixit             11
# Khushboo Priya            18
# Madhulika G               17
# Mahesh Sarade             36
# Maitry                     5
# Manjunatha A               8
# Mithun S                  14
# Mukesh                     3
# Muskan Garg               12
# Nandani Gupta             11
# Nishtha Jain              18
# Nitin M                    1
# ...

# %%
#3. Total query that you hvae taken 
df2.head(3)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
# 2      3 2022-07-30     Ameya Jain           14               0:00:30
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
# 2                 0:11:36            4.55              11         30
#
#    conv_date
# 0         30
# 1         30
# 2         30

# %%
df2.groupby(['Agent Name'])['Total Chats'].sum().to_frame()
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %%
#4. total Feedback that you have received

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date
# 0         30
# 1         30

# %%
df2.groupby(['Agent Name'])['Total Feedback'].sum().to_frame()
# Out:
#                Total Feedback
# Agent Name
# Abhishek                    0
# Aditya                      0
# Aditya Shinde             153
# Aditya_iot                131
# Amersh                      0
# ...                       ...
# Uday Mishra                 0
# Vasanth P                   0
# Vivek                      20
# Wasim                     284
# Zeeshan                   335
#
# [70 rows x 1 columns]

# %%
#5 agent name who have average rating between 3.5 to 4

# %%
df2[(df2['Average Rating']>3.5) & (df2['Average Rating']<4)][['Agent Name','Average Rating']]
# Out:
#                Agent Name  Average Rating
# 4                  Swati             3.67
# 10           Manjunatha A            3.60
# 76          Prateek _iot             3.75
# 78          Nandani Gupta            3.79
# 80          Jaydeep Dixit            3.95
# ...                   ...             ...
# 1869  Boktiar Ahmed Bappy            3.78
# 1874        Ayushi Mishra            3.80
# 1941       Jawala Prakash            3.80
# 2021        Aditya Shinde            3.54
# 2023     Deepranjan Gupta            3.71
#
# [78 rows x 2 columns]

# %%
# 6 . Agent name who have rating lesss then 3.5

# %%
df2[(df2['Average Rating']<3.5)][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 1          Nandani Gupta            3.14
# 19      Hitesh Choudhary            0.00
# 20            Sanjeevan             0.00
# 21              Anirudh             0.00
# 22      Shiva Srivastava            0.00
# ...                  ...             ...
# 2155   Sowmiya Sivakumar            0.00
# 2156             Nitin M            0.00
# 2157              Vivek             0.00
# 2158       Ayushi Mishra            0.00
# 2159  Chaitra K Hiremath            0.00
#
# [1474 rows x 2 columns]

# %%
#7 . agent name who have rating more then 4.5

# %%
df2[df2['Average Rating']> 4.5][['Agent Name','Average Rating']]
# Out:
#               Agent Name  Average Rating
# 2             Ameya Jain            4.55
# 3          Mahesh Sarade            4.71
# 5                Mukesh             4.62
# 6        Saikumarreddy N            5.00
# 7          Sanjeev Kumar            5.00
# ...                  ...             ...
# 2100      Shubham Sharma            5.00
# 2101       Jaydeep Dixit            4.77
# 2102  Shivananda Sonwane            4.86
# 2103      Khushboo Priya            4.61
# 2104     Hrisikesh Neogi            4.56
#
# [307 rows x 2 columns]

# %%
# 8 . how many feedaback agents have received more then 4.5 average

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date
# 0         30
# 1         30

# %%
fd = df2[(df2['Average Rating']>4.5)].groupby('Agent Name')['Total Feedback'].sum().to_frame()

# %%
fd
# Out:
#                         Total Feedback
# Agent Name
# Aditya Shinde                       73
# Aditya_iot                          43
# Ameya Jain                         150
# Anirudh                              2
# Ankitjha                             1
# Aravind                            178
# Ayushi Mishra                       75
# Bharath                            231
# Boktiar Ahmed Bappy                 52
# Chaitra K Hiremath                   5
# Deepranjan Gupta                    83
# Harikrishnan Shaji                  80
# Hrisikesh Neogi                    183
# Ishawant Kumar                      79
# Jawala Prakash                      33
# Jayant Kumar                         7
# Jaydeep Dixit                      179
# Khushboo Priya                     134
# Madhulika G                         67
# Mahesh Sarade                       46
# Maitry                              81
# Manjunatha A                       132
# Mithun S                            93
# ...

# %%
#9 . average weekly response time for each agent 
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date
# 0         30
# 1         30

# %%
def sec(time):
    """Get seconds from time."""
    h, m, s = time.split(':')
    return int(h) * 3600 + int(m) * 60 + int(s)

# %%
sec('1:10:50')
# Out:
# 4250

# %%
resp_sec =[]
for i in df2['Average Response Time']:
    resp_sec.append(sec(i))
df2['conv_time_insec'] = resp_sec

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date  conv_time_insec
# 0         30               38
# 1         30               75

# %%
RT = df2.groupby(['Agent Name','conv_week'])['conv_time_insec'].mean().to_frame()

# %%
RT
# Out:
#                       conv_time_insec
# Agent Name conv_week
# Abhishek   26                0.000000
#            27                0.000000
#            28                0.000000
#            29                0.000000
#            30                0.000000
# ...                               ...
# Zeeshan    26                0.000000
#            27               23.571429
#            28              123.428571
#            29               62.857143
#            30               63.833333
#
# [350 rows x 1 columns]

# %%
#10 . average weekely resolution time for each agents

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date  conv_time_insec
# 0         30               38
# 1         30               75

# %%
resoltion_time = []
for j in df2['Average Resolution Time']:
    resoltion_time.append(sec(j))

df2['conv_resolut_time'] = resoltion_time

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date  conv_time_insec  conv_resolut_time
# 0         30               38                260
# 1         30               75               1705

# %%
df2.groupby(['Agent Name' , 'conv_week' ])['conv_resolut_time'].mean().to_frame()
# Out:
#                       conv_resolut_time
# Agent Name conv_week
# Abhishek   26                  0.000000
#            27                  0.000000
#            28                  0.000000
#            29                  0.000000
#            30                  0.000000
# ...                                 ...
# Zeeshan    26                  0.000000
#            27                323.000000
#            28                984.285714
#            29                794.285714
#            30                773.500000
#
# [350 rows x 1 columns]

# %%
#11 . list of all agents name

# %%
AN = df2.groupby(['Agent Name']) ['Agent Name'].count()

# %%
AN
# Out:
# Agent Name
# Abhishek         30
# Aditya           30
# Aditya Shinde    30
# Aditya_iot       30
# Amersh           30
#                  ..
# Uday Mishra      30
# Vasanth P        30
# Vivek            30
# Wasim            30
# Zeeshan          30
# Name: Agent Name, Length: 70, dtype: int64

# %%
p = set(df2['Agent Name'])
print(p)
len(p)
# Out:
# {'Maitry ', 'Muskan Garg', 'Nishtha Jain', 'Nandani Gupta', 'Abhishek ', 'Sanjeev Kumar', 'Sandipan Saha', 'Mukesh Rao ', 'Sanjeevan ', 'Ankit Sharma', 'Jayant Kumar', 'Hrisikesh Neogi', 'Spuri ', 'Shivananda Sonwane', 'Zeeshan ', 'Dibyanshu ', 'Anirudh ', 'Ankitjha ', 'Amersh ', 'Madhulika G', 'Deepranjan Gupta', 'Shiva Srivastava', 'Vasanth P', 'Anurag Tiwari', 'Manjunatha A', 'Sowmiya Sivakumar', 'Chaitra K Hiremath', 'Mahak ', 'Harikrishnan Shaji', 'Suraj S Bilgi', 'Aditya_iot ', 'Sudhanshu Kumar', 'Nitin M', 'Samprit ', 'Ameya Jain', 'Hyder Abbas', 'Wasim ', 'Boktiar Ahmed Bappy', 'Aravind ', 'Mithun S', 'Mukesh ', 'Vivek ', 'Tarun ', 'Mahesh Sarade', 'Maneesh ', 'Prerna Singh', 'Saurabh Shukla', 'Rohan ', 'Shivan K', 'Saikumarreddy N', 'Rishav Dash', 'Ayushi Mishra', 'Prateek _iot ', 'Bharath ', 'Swati ', 'Ashish ', 'Shubham Sharma', 'Shivan_S ', 'Saif Khan', 'Jaydeep Dixit', 'Aditya ', 'Aditya Shinde', 'Hitesh Choudhary', 'Ishawant Kumar', 'Prabir Kumar Satapathy', 'Ashad Nasi
# ...

# %%
#12 . percentage of chat on which they have received a feedback

# %%
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date  conv_time_insec  conv_resolut_time
# 0         30               38                260
# 1         30               75               1705

# %%
df2.groupby(['Agent Name' , 'Total Feedback'])['Total Chats'].sum().to_frame()
# Out:
#                               Total Chats
# Agent Name    Total Feedback
# Abhishek      0                         0
# Aditya        0                         0
# Aditya Shinde 0                         0
#               7                         8
#               8                        17
# ...                                   ...
# Zeeshan       22                       35
#               24                       99
#               25                       78
#               28                       82
#               35                       92
#
# [564 rows x 1 columns]

# %%
#13 . Total contributation hour for each and every agents weekly basis 
df2.head(2)
# Out:
#    SL No       Date     Agent Name  Total Chats Average Response Time  \
# 0      1 2022-07-30   Prerna Singh           11               0:00:38
# 1      2 2022-07-30  Nandani Gupta           11               0:01:15
#
#   Average Resolution Time  Average Rating  Total Feedback  conv_week  \
# 0                 0:04:20            4.11               9         30
# 1                 0:28:25            3.14               7         30
#
#    conv_date  conv_time_insec  conv_resolut_time
# 0         30               38                260
# 1         30               75               1705

# %%
df1.head(2)
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17

# %%
df1.dtypes
# Out:
# SL No           int64
# Agent          object
# Date           object
# Login Time     object
# Logout Time    object
# Duration       object
# dtype: object

# %%
df1['conv_year'] = pd.to_datetime(df1['Date']).dt.year

# %%
df1['conv_week'] = pd.to_datetime(df1['Date']).dt.isocalendar().week

# %%
df1['conv_month'] = pd.to_datetime(df1['Date']).dt.month

# %%
df1.tail()
# Out:
#      SL No           Agent       Date Login Time Logout Time   Duration  \
# 995    996    Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997         Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998  Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999    Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000           Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#      conv_year  conv_week  conv_month
# 995       2022         29           7
# 996       2022         29           7
# 997       2022         29           7
# 998       2022         29           7
# 999       2022         26           7

# %%
def duration_in_sec(time):
    h,m,s = time.split(":")
    return int(h)*3600 + int(m)*60 + int(s)

# %%
duration_in_sec('1:10:30')
# Out:
# 4230

# %%
Duratime = []
for k in df1['Duration']:
    Duratime.append(duration_in_sec(k))
df1['Dura_in_Sec'] = Duratime

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
#      conv_year  conv_week  conv_month  Dura_in_Sec
# ...

# %%
df1.groupby(['Agent' , 'conv_week'])['Dura_in_Sec'].sum().to_frame()
# Out:
#                          Dura_in_Sec
# Agent         conv_week
# Aditya Shinde 30                 130
# Aditya_iot    29               21943
#               30               34689
# Amersh        30               11030
# Ameya Jain    29               86699
# ...                              ...
# Tarun         26             1850900
# Wasim         29               70652
#               30              102793
# Zeeshan       29               87939
#               30               88780
#
# [89 rows x 1 columns]

# %%
duraH = []
for g in df1['Dura_in_Sec']:
    duraH.append(g/3600)
df1['dura_in_Hours'] = duraH

# %%
df1
# Out:
#      SL No               Agent       Date Login Time Logout Time   Duration  \
# 0        1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39   02:04:10
# 1        2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16   00:00:17
# 2        3       Nandani Gupta  30-Jul-22   15:04:24    17:31:07   02:26:42
# 3        4     Hrisikesh Neogi  30-Jul-22   14:34:29    15:19:35   00:45:06
# 4        5              Mukesh  30-Jul-22   14:03:15    15:11:52   01:08:36
# ..     ...                 ...        ...        ...         ...        ...
# 995    996        Manjunatha A  20-Jul-22   09:03:51    15:02:28   05:58:37
# 996    997             Bharath  20-Jul-22   09:00:49    15:01:32   06:00:43
# 997    998      Khushboo Priya  20-Jul-22   08:59:20    14:26:55   05:27:34
# 998    999        Nishtha Jain  20-Jul-22   08:43:55    14:00:33   05:16:38
# 999   1000               Tarun  01-Jul-22   01:52:47    12:01:07  514:08:20
#
# ...

# %%
df1.groupby(['Agent','conv_week'])['dura_in_Hours'].sum().to_frame()
# Out:
#                          dura_in_Hours
# Agent         conv_week
# Aditya Shinde 30              0.036111
# Aditya_iot    29              6.095278
#               30              9.635833
# Amersh        30              3.063889
# Ameya Jain    29             24.083056
# ...                                ...
# Tarun         26            514.138889
# Wasim         29             19.625556
#               30             28.553611
# Zeeshan       29             24.427500
#               30             24.661111
#
# [89 rows x 1 columns]

# %%
p=df1.groupby(['Agent','conv_week'])['dura_in_Hours'].sum().to_frame()
p.tail()
# Out:
#                    dura_in_Hours
# Agent   conv_week
# Tarun   26            514.138889
# Wasim   29             19.625556
#         30             28.553611
# Zeeshan 29             24.427500
#         30             24.661111

# %%
#total percentage of active hour for a month 
df1.head(2)
# Out:
#    SL No               Agent       Date Login Time Logout Time  Duration  \
# 0      1  Shivananda Sonwane  30-Jul-22   15:35:29    17:39:39  02:04:10
# 1      2      Khushboo Priya  30-Jul-22   15:06:59    15:07:16  00:00:17
#
#    conv_year  conv_week  conv_month  Dura_in_Sec  dura_in_Hours
# 0       2022         30           7         7450       2.069444
# 1       2022         30           7           17       0.004722

# %%
df1.groupby('conv_month')['dura_in_Hours'].sum()
# Out:
# conv_month
# 7    2179.964444
# Name: dura_in_Hours, dtype: float64

# %%
perct = []
for p in df1['dura_in_Hours']:
    perct.append(p*100/2179.96)
df1['perct_hours'] = perct

# %%
df1.groupby(['Agent','conv_month'])['perct_hours'].sum().to_frame()
# Out:
#                                    perct_hours
# Agent                  conv_month
# Aditya Shinde          7              0.001657
# Aditya_iot             7              0.721624
# Amersh                 7              0.140548
# Ameya Jain             7              1.930107
# Ankitjha               7              0.103990
# Anurag Tiwari          7              0.127474
# Aravind                7              1.114661
# Ayushi Mishra          7              1.748732
# Bharath                7              2.205392
# Boktiar Ahmed Bappy    7              1.847218
# Chaitra K Hiremath     7              1.574596
# Deepranjan Gupta       7              4.875102
# Dibyanshu              7              2.412697
# Harikrishnan Shaji     7              2.464023
# Hrisikesh Neogi        7              2.640810
# Hyder Abbas            7              0.017801
# Ineuron Intelligence   7              0.066451
# Ishawant Kumar         7              2.375222
# ...
